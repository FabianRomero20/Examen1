# %%
import os, geopandas as gpd

municipios=gpd.read_file(os.path.join("maps","Municipios","municipio_geo.shp"))
ciudades=gpd.read_file(os.path.join("maps","Ciudades","CapitalDepartamental.shp"))
rios=gpd.read_file(os.path.join("maps","Rios","rios_poly_250000.shp"))

# %%
#Qué tipo es
type(municipios)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#Qué tipo es
type(rios)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#Qué tipo es
type(ciudades)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#Dimensión
municipios.shape
# Out:
# (339, 7)

# %%
#Dimensión
rios.shape
# Out:
# (784, 8)

# %%
#Dimensión
ciudades.shape
# Out:
# (9, 4)

# %%
#Observamos un poco del contenido
municipios.head()
# Out:
#    id    c_ut  DEPARTAMEN         PROVINCIA  MUNICIPIO          CAPITAL  \
# 0   0  040505       Oruro           Litoral  Esmeralda        Esmeralda
# 1   1  050203      Potosí   Rafael Bustillo  Llallagua        Llallagua
# 2   2  050702      Potosí  Alonso de Ibáñez   Caripuyo         Caripuyo
# 3   3  030201  Cochabamba           Campero    Aiquile          Aiquile
# 4   4  050701      Potosí  Alonso de Ibáñez     Sacaca  Villa de Sacaca
#
#                                             geometry
# 0  POLYGON ((-68.26703 -18.81616, -68.26279 -18.8...
# 1  POLYGON ((-66.42997 -18.25647, -66.42895 -18.2...
# 2  POLYGON ((-66.55964 -18.07798, -66.55916 -18.0...
# 3  POLYGON ((-65.21781 -17.92884, -65.21745 -17.9...
# 4  POLYGON ((-66.31737 -17.95174, -66.31672 -17.9...

# %%
#Observamos un poco del tipo de contenido que tiene
municipios.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          339 non-null    int32
#  1   c_ut        339 non-null    object
#  2   DEPARTAMEN  339 non-null    object
#  3   PROVINCIA   339 non-null    object
#  4   MUNICIPIO   339 non-null    object
#  5   CAPITAL     339 non-null    object
#  6   geometry    339 non-null    geometry
# dtypes: geometry(1), int32(1), object(5)
# memory usage: 17.3+ KB

# %%
#Observamos un poco del contenido
rios.head()
# Out:
#                gml_id CODIGO   DESCRIPCIO    CATEGORIA  \
# 0  rios_poly_250000.1  BH140  RIOS DOBLES  HIDROGRAFIA
# 1  rios_poly_250000.2  BH140  RIOS DOBLES  HIDROGRAFIA
# 2  rios_poly_250000.3  BH140  RIOS DOBLES  HIDROGRAFIA
# 3  rios_poly_250000.4  BH140  RIOS DOBLES  HIDROGRAFIA
# 4  rios_poly_250000.5  BH140  RIOS DOBLES  HIDROGRAFIA
#
#                 SUBCATEGOR             NOMBRE CODIGO_OBJ  \
# 0  HIDROGRAFIA CONTINENTAL  RIO GRANDE GUAPAY     BH1403
# 1  HIDROGRAFIA CONTINENTAL         RIO GRANDE     BH1403
# 2  HIDROGRAFIA CONTINENTAL         RIO MIZQUE     BH1403
# 3  HIDROGRAFIA CONTINENTAL         RIO GRANDE     BH1403
# 4  HIDROGRAFIA CONTINENTAL          RIO PIRAY     BH1403
#
#                                             geometry
# 0  POLYGON ((-7049039.916 -2143276.833, -7049039....
# 1  POLYGON ((-7159287.544 -2121845.687, -7159300....
# 2  POLYGON ((-7160691.272 -2115108.489, -7160749....
# 3  POLYGON ((-7159140.859 -2124016.293, -7159127....
# 4  POLYGON ((-7069655.841 -2056296.800, -7069446....

# %%
#Observamos un poco del tipo de contenido que tiene
rios.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   gml_id      784 non-null    object
#  1   CODIGO      784 non-null    object
#  2   DESCRIPCIO  783 non-null    object
#  3   CATEGORIA   778 non-null    object
#  4   SUBCATEGOR  782 non-null    object
#  5   NOMBRE      321 non-null    object
#  6   CODIGO_OBJ  767 non-null    object
#  7   geometry    784 non-null    geometry
# dtypes: geometry(1), object(7)
# memory usage: 49.1+ KB

# %%
#Observamos un poco del contenido
ciudades.head()
# Out:
#                    gml_id  ID      NOMBRE                     geometry
# 0  CapitalDepartamental.1   0      COBIJA  POINT (-68.77689 -11.03397)
# 1  CapitalDepartamental.2   0    TRINIDAD  POINT (-64.92070 -14.84987)
# 2  CapitalDepartamental.3   0      LA PAZ  POINT (-68.13798 -16.49165)
# 3  CapitalDepartamental.4   0  COCHABAMBA  POINT (-66.17044 -17.38918)
# 4  CapitalDepartamental.5   0       ORURO  POINT (-67.11293 -17.96623)

# %%
#Observamos un poco del tipo de contenido que tiene
ciudades.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gml_id    9 non-null      object
#  1   ID        9 non-null      int64
#  2   NOMBRE    9 non-null      object
#  3   geometry  9 non-null      geometry
# dtypes: geometry(1), int64(1), object(2)
# memory usage: 416.0+ bytes

# %%
#plot simple de todos
municipios.plot()
rios.plot()
ciudades.plot()
# Out:
# <AxesSubplot:>

# %%
municipios.plot(facecolor="palegreen",#color de relleno poligonal
               edgecolor='black', #color de lineas
               linewidth=0.4) #grosor de lineas
# Out:
# <AxesSubplot:>

# %%
rios.plot(edgecolor='blue', 
            linewidth=0.3,
            linestyle='solid')
# Out:
# <AxesSubplot:>

# %%
ciudades.plot(marker='D', #tipo de marca
            color='red', 
            markersize=5,
            alpha=1) #transparencia
# Out:
# <AxesSubplot:>

# %%
municipios.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
rios.crs
# Out:
# <Projected CRS: PROJCS["Google_Maps_Global_Mercator",GEOGCS["WGS 8 ...>
# Name: Google_Maps_Global_Mercator
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Mercator (variant B)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
ciudades.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#Nos damos cuenta que el crs de rios no es el mismo
#Entonces, lo igualaremos a los demás
rios=rios.to_crs(municipios.crs)
# Out:
# ---------------------------------------------------------------------------
# ProjError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18524\711318981.py in <module>
#       1 #Nos damos cuenta que el crs de rios no es el mismo
#       2 #Entonces, lo igualaremos a los demás
# ----> 3 rios=rios.to_crs(municipios.crs)
#
# ~\anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#    1362         else:
#    1363             df = self.copy()
# -> 1364         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#    1365         df.geometry = geom
#    1366         if not inplace:
#
# ~\anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#    1122         """
#    1123         return GeoSeries(
# -> 1124             self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1125         )
#    1126
#
# ~\anaconda3\lib\site-packages\geopandas\array.py in to_crs(self, crs, epsg)
#     777         transformer = Transformer.from_crs(self.crs, crs, always_xy=True)
#     778
# --> 779         new_data = vectorized.transform(self.data, transformer.transform)
#     780         return GeometryArray(new_data, crs=crs)
#     781
#
# ~\anaconda3\lib\site-packages\geopandas\_vectorized.py in transform(data, func)
#    1112
#    1113         coords_z = get_coordinates(data[has_z], include_z=True)
# -> 1114         new_coords_z = func(coords_z[:, 0], coords_z[:, 1], coords_z[:, 2])
#    1115         result[has_z] = set_coordinates(data[has_z].copy(), np.array(new_coords_z).T)
#    1116
#
# ~\anaconda3\lib\site-packages\pyproj\transformer.py in transform(self, xx, yy, zz, tt, radians, errcheck, direction)
#     428             intime = None
#     429         # call pj_transform.  inx,iny,inz buffers modified in place.
# --> 430         self._transformer._transform(
#     431             inx,
#     432             iny,
#
# pyproj/_transformer.pyx in pyproj._transformer._Transformer._transform()
#
# ProjError: x, y, z, and time must be same size
